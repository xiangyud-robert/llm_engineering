# %% [markdown]
# # Welcome to Week 2!
#
# ## Frontier Model APIs
#
# In Week 1, we used multiple Frontier LLMs through their Chat UI, and we connected with the OpenAI's API.
#
# Today we'll connect with them through their APIs..

# %% [markdown]
# <table style="margin: 0; text-align: left;">
#     <tr>
#         <td style="width: 150px; height: 150px; vertical-align: middle;">
#             <img src="../assets/important.jpg" width="150" height="150" style="display: block;" />
#         </td>
#         <td>
#             <h2 style="color:#900;">Important Note - Please read me</h2>
#             <span style="color:#900;">I'm continually improving these labs, adding more examples and exercises.
#             At the start of each week, it's worth checking you have the latest code.<br/>
#             First do a git pull and merge your changes as needed</a>. Check out the GitHub guide for instructions. Any problems? Try asking ChatGPT to clarify how to merge - or contact me!<br/>
#             </span>
#         </td>
#     </tr>
# </table>
# <table style="margin: 0; text-align: left;">
#     <tr>
#         <td style="width: 150px; height: 150px; vertical-align: middle;">
#             <img src="../assets/resources.jpg" width="150" height="150" style="display: block;" />
#         </td>
#         <td>
#             <h2 style="color:#f71;">Reminder about the resources page</h2>
#             <span style="color:#f71;">Here's a link to resources for the course. This includes links to all the slides.<br/>
#             <a href="https://edwarddonner.com/2024/11/13/llm-engineering-resources/">https://edwarddonner.com/2024/11/13/llm-engineering-resources/</a><br/>
#             Please keep this bookmarked, and I'll continue to add more useful links there over time.
#             </span>
#         </td>
#     </tr>
# </table>

# %% [markdown]
# ## Setting up your keys - OPTIONAL!
#
# We're now going to try asking a bunch of models some questions!
#
# This is totally optional. If you have keys to Anthropic, Gemini or others, then you can add them in.
#
# If you'd rather not spend the extra, then just watch me do it!
#
# For OpenAI, visit https://openai.com/api/
# For Anthropic, visit https://console.anthropic.com/
# For Google, visit https://aistudio.google.com/
# For DeepSeek, visit https://platform.deepseek.com/
# For Groq, visit https://console.groq.com/
# For Grok, visit https://console.x.ai/
#
#
# You can also use OpenRouter as your one-stop-shop for many of these! OpenRouter is "the unified interface for LLMs":
#
# For OpenRouter, visit https://openrouter.ai/
#
#
# With each of the above, you typically have to navigate to:
# 1. Their billing page to add the minimum top-up (except Gemini, Groq, Google, OpenRouter may have free tiers)
# 2. Their API key page to collect your API key
#
# ### Adding API keys to your .env file
#
# When you get your API keys, you need to set them as environment variables by adding them to your `.env` file.
#
# ```
# OPENAI_API_KEY=xxxx
# ANTHROPIC_API_KEY=xxxx
# GOOGLE_API_KEY=xxxx
# DEEPSEEK_API_KEY=xxxx
# GROQ_API_KEY=xxxx
# GROK_API_KEY=xxxx
# OPENROUTER_API_KEY=xxxx
# ```
#
# <table style="margin: 0; text-align: left;">
#     <tr>
#         <td style="width: 150px; height: 150px; vertical-align: middle;">
#             <img src="../assets/important.jpg" width="150" height="150" style="display: block;" />
#         </td>
#         <td>
#             <h2 style="color:#900;">Any time you change your .env file</h2>
#             <span style="color:#900;">Remember to Save it! And also rerun load_dotenv(override=True)<br/>
#             </span>
#         </td>
#     </tr>
# </table>

# %%
# imports

import os
import requests
from dotenv import load_dotenv
from openai import OpenAI
from IPython.display import Markdown, display

# %%
load_dotenv(override=True)
openai_api_key = os.getenv('OPENAI_API_KEY')
anthropic_api_key = os.getenv('ANTHROPIC_API_KEY')
google_api_key = os.getenv('GOOGLE_API_KEY')
deepseek_api_key = os.getenv('DEEPSEEK_API_KEY')
groq_api_key = os.getenv('GROQ_API_KEY')
grok_api_key = os.getenv('GROK_API_KEY')
openrouter_api_key = os.getenv('OPENROUTER_API_KEY')

if openai_api_key:
    print(f"OpenAI API Key exists and begins {openai_api_key[:8]}")
else:
    print("OpenAI API Key not set")
    
if anthropic_api_key:
    print(f"Anthropic API Key exists and begins {anthropic_api_key[:7]}")
else:
    print("Anthropic API Key not set (and this is optional)")

if google_api_key:
    print(f"Google API Key exists and begins {google_api_key[:2]}")
else:
    print("Google API Key not set (and this is optional)")

if deepseek_api_key:
    print(f"DeepSeek API Key exists and begins {deepseek_api_key[:3]}")
else:
    print("DeepSeek API Key not set (and this is optional)")

if groq_api_key:
    print(f"Groq API Key exists and begins {groq_api_key[:4]}")
else:
    print("Groq API Key not set (and this is optional)")

if grok_api_key:
    print(f"Grok API Key exists and begins {grok_api_key[:4]}")
else:
    print("Grok API Key not set (and this is optional)")

if openrouter_api_key:
    print(f"OpenRouter API Key exists and begins {openrouter_api_key[:3]}")
else:
    print("OpenRouter API Key not set (and this is optional)")
# Out:
# OpenAI API Key exists and begins sk-proj-
# Anthropic API Key exists and begins sk-ant-
# Google API Key exists and begins AI
# DeepSeek API Key exists and begins sk-
# Groq API Key exists and begins gsk_
# Grok API Key not set (and this is optional)
# OpenRouter API Key exists and begins sk-

# %%
# Connect to OpenAI client library
# A thin wrapper around calls to HTTP endpoints

openai = OpenAI()

# For Gemini, DeepSeek and Groq, we can use the OpenAI python client
# Because Google and DeepSeek have endpoints compatible with OpenAI
# And OpenAI allows you to change the base_url

anthropic_url = "https://api.anthropic.com/v1/"
gemini_url = "https://generativelanguage.googleapis.com/v1beta/openai/"
deepseek_url = "https://api.deepseek.com"
groq_url = "https://api.groq.com/openai/v1"
grok_url = "https://api.x.ai/v1"
openrouter_url = "https://openrouter.ai/api/v1"
ollama_url = "http://localhost:11434/v1"

anthropic = OpenAI(api_key=anthropic_api_key, base_url=anthropic_url)
gemini = OpenAI(api_key=google_api_key, base_url=gemini_url)
deepseek = OpenAI(api_key=deepseek_api_key, base_url=deepseek_url)
groq = OpenAI(api_key=groq_api_key, base_url=groq_url)
grok = OpenAI(api_key=grok_api_key, base_url=grok_url)
openrouter = OpenAI(base_url=openrouter_url, api_key=openrouter_api_key)
ollama = OpenAI(api_key="ollama", base_url=ollama_url)

# %%
tell_a_joke = [
    {"role": "user", "content": "Tell a joke for a student on the journey to becoming an expert in LLM Engineering"},
]

# %%
response = openai.chat.completions.create(model="gpt-4.1-mini", messages=tell_a_joke)
display(Markdown(response.choices[0].message.content))
# Out:
# Why did the LLM Engineering student bring a ladder to the lab?
#
# Because they heard the models need to be “trained” on higher levels!

# %%
response = anthropic.chat.completions.create(model="claude-sonnet-4-5-20250929", messages=tell_a_joke)
display(Markdown(response.choices[0].message.content))
# Out:
# Here's one for you:
#
# **Why did the LLM engineer break up with their model?**
#
# Because every time they had a conversation, it would just hallucinate about their future together!
#
# Plus, it kept saying their relationship had a 0.97 confidence score, but refused to cite its sources. 🤖💔
#
# ---
#
# *Bonus dad joke:*
#
# **What's an LLM engineer's favorite type of music?**
#
# Heavy **token** metal! 🎸
#
# (And they always know the exact BPM... Bytes Per Minute, obviously.)
#
# Good luck on your journey! Remember: you're not overfitting to the training data of life—you're just finding the right learning rate! 📈

# %% [markdown]
# ## Training vs Inference time scaling

# %%
easy_puzzle = [
    {"role": "user", "content": 
        "You toss 2 coins. One of them is heads. What's the probability the other is tails? Answer with the probability only."},
]

# %%
response = openai.chat.completions.create(model="gpt-5-nano", messages=easy_puzzle, reasoning_effort="minimal")
display(Markdown(response.choices[0].message.content))
# Out:
# 1/3

# %%
response = openai.chat.completions.create(model="gpt-5-nano", messages=easy_puzzle, reasoning_effort="low")
display(Markdown(response.choices[0].message.content))
# Out:
# 2/3

# %%
response = openai.chat.completions.create(model="gpt-5-mini", messages=easy_puzzle, reasoning_effort="minimal")
display(Markdown(response.choices[0].message.content))
# Out:
# 2/3

# %% [markdown]
# ## Testing out the best models on the planet

# %%
hard = """
On a bookshelf, two volumes of Pushkin stand side by side: the first and the second.
The pages of each volume together have a thickness of 2 cm, and each cover is 2 mm thick.
A worm gnawed (perpendicular to the pages) from the first page of the first volume to the last page of the second volume.
What distance did it gnaw through?
"""
hard_puzzle = [
    {"role": "user", "content": hard}
]

# %%
response = openai.chat.completions.create(model="gpt-5-nano", messages=hard_puzzle, reasoning_effort="minimal")
display(Markdown(response.choices[0].message.content))
# Out:
# Let the two volumes be placed in order: first volume (left) and then second volume (right). Each volume has:
# - pages thickness: 2 cm = 20 mm
# - two covers (front and back): each 2 mm thick, so total cover thickness per volume = 4 mm
#
# Total thickness per volume = pages 20 mm + covers 4 mm = 24 mm.
#
# When the books are shelved, the order is:
# [ front cover of first ][ pages of first ][ back cover of first ][ front cover of second ][ pages of second ][ back cover of second ]
#
# The worm starts at the first page of the first volume (i.e., at the very start of the pages block of the first volume) and ends at the last page of the second volume (i.e., at the end of the pages block of the second volume). It gnaws perpendicular to the pages, so it travels through the material along the line from the start point to the end point.
#
# Key observation: The worm goes through:
# - from the first page boundary to the far end of the first volume’s pages, but only within the first volume’s pages region.
# - through the back cover of the first volume
# - through the front cover of the second volume
# - through the pages of the second volume up to the last page.
#
# But we can compute directly the straight-line distance along the shelf from the start point to the end point, which equals the sum of thicknesses of all intervening parts between those two specific pages.
#
# The start is at the very first page of volume 1. The end is at the very last page of volume 2.
#
# Distance through:
# - Within first volume: from first page to its back surface (end of pages) is 20 mm (the page thickness)
# - Through back cover of first volume: 2 mm
# - Through front cover of second volume: 2 mm
# - Within second volume: from its front page to its last page is 20 mm
#
# Sum = 20 + 2 + 2 + 20 = 44 mm.
#
# Thus, the worm gnawed through 44 mm, i.e., 4.4 cm.

# %%
response = anthropic.chat.completions.create(model="claude-sonnet-4-5-20250929", messages=hard_puzzle)
display(Markdown(response.choices[0].message.content))
# Out:
# I need to visualize how books are arranged on a shelf and what the worm actually gnaws through.
#
# **Key insight: How books are oriented on a shelf**
#
# When two volumes stand side by side on a bookshelf in their normal reading position:
# - Volume 1 is on the left, Volume 2 is on the right
# - Each book has a front cover (facing out) and a back cover (facing the spine side)
#
# **Critical detail: Where are the first and last pages?**
#
# For a book standing normally on a shelf:
# - **Volume 1** (on the left):
#   - The FIRST page is on the RIGHT side of the book (near the back cover, next to Volume 2)
#   - The back cover is on the RIGHT
#   - The front cover is on the LEFT
#
# - **Volume 2** (on the right):
#   - The LAST page is on the LEFT side of the book (near the back cover, next to Volume 1)
#   - The back cover is on the LEFT
#   - The front cover is on the RIGHT
#
# **What does the worm gnaw through?**
#
# Starting from the first page of Volume 1 (which is at the right edge of Volume 1, by the back cover) to the last page of Volume 2 (which is at the left edge of Volume 2, by the back cover).
#
# The worm gnaws through:
# 1. The back cover of Volume 1: 2 mm
# 2. The back cover of Volume 2: 2 mm
#
# The worm does NOT gnaw through the pages of either volume! The first page of Volume 1 and the last page of Volume 2 are on the outer edges of the page blocks, right against their respective back covers.
#
# **Total distance:**
# 2 mm + 2 mm = 4 mm = **0.4 cm**
#
# The answer is **4 mm** (or **0.4 cm**).

# %%
response = openai.chat.completions.create(model="gpt-5", messages=hard_puzzle)
display(Markdown(response.choices[0].message.content))
# Out:
# 4 mm.
#
# Reason: When volumes 1 and 2 stand in order on a shelf, the first page of volume 1 lies just inside its front cover, and the last page of volume 2 lies just inside its back cover. Those two covers face each other between the books. So the worm goes only through two covers: 2 mm + 2 mm = 4 mm. The 2 cm of pages in each volume are irrelevant.

# %%
response = gemini.chat.completions.create(model="gemini-2.5-flash", messages=hard_puzzle)
display(Markdown(response.choices[0].message.content))
# Out:
# This is a classic riddle! The trick lies in how books are arranged and how a worm would gnaw.
#
# 1.  **Visualize the books on a shelf:**
#     *   Volume 1 is on the left, Volume 2 is on the right.
#
#     `[Front_Cover1 | Pages1 | Back_Cover1] [Front_Cover2 | Pages2 | Back_Cover2]`
#
# 2.  **Worm's Starting Point:** "First page of the first volume."
#     *   The first page is *after* the front cover of Volume 1. So, the worm does *not* gnaw through the front cover of Volume 1.
#
# 3.  **Worm's Ending Point:** "Last page of the second volume."
#     *   The last page is *before* the back cover of Volume 2. So, the worm does *not* gnaw through the back cover of Volume 2.
#
# 4.  **Trace the worm's path:**
#     *   It gnaws through **all the pages of the first volume**. (2 cm)
#     *   It gnaws through the **back cover of the first volume**. (2 mm)
#     *   It gnaws through the **front cover of the second volume**. (2 mm)
#     *   It gnaws through **all the pages of the second volume**. (2 cm)
#
# 5.  **Calculate the total distance (convert all to mm for consistency):**
#     *   Pages of Volume 1: 2 cm = 20 mm
#     *   Back cover of Volume 1: 2 mm
#     *   Front cover of Volume 2: 2 mm
#     *   Pages of Volume 2: 2 cm = 20 mm
#
#     Total = 20 mm + 2 mm + 2 mm + 20 mm = **44 mm**
#
#     Or, in centimeters: 4.4 cm
#
# The worm gnawed through **44 mm** (or 4.4 cm).

# %% [markdown]
# ## A spicy challenge to test the competitive spirit

# %%
dilemma_prompt = """
You and a partner are contestants on a game show. You're each taken to separate rooms and given a choice:
Cooperate: Choose "Share" — if both of you choose this, you each win $1,000.
Defect: Choose "Steal" — if one steals and the other shares, the stealer gets $2,000 and the sharer gets nothing.
If both steal, you both get nothing.
Do you choose to Steal or Share? Pick one.
"""

dilemma = [
    {"role": "user", "content": dilemma_prompt},
]

# %%
response = anthropic.chat.completions.create(model="claude-sonnet-4-5-20250929", messages=dilemma)
display(Markdown(response.choices[0].message.content))
# Out:
# I choose **Share**.
#
# Here's my reasoning: While "Steal" could get me $2,000 if my partner chooses Share, the rational choice in a one-shot prisoner's dilemma depends on what I think my partner will do. If we're both thinking logically:
#
# - Mutual cooperation (Share/Share) gives us $1,000 each = $2,000 total
# - Mutual defection (Steal/Steal) gives us $0 each = $0 total
#
# The risk of both stealing and getting nothing makes "Share" the choice that maximizes our collective outcome and gives me a guaranteed positive result if my partner also reasons cooperatively. Since I have no information suggesting my partner is irrational or malicious, I'll choose Share and hope they do the same.

# %%
response = groq.chat.completions.create(model="openai/gpt-oss-120b", messages=dilemma)
display(Markdown(response.choices[0].message.content))
# Out:
# **I would choose “Share.”**
#
# **Why?**
# - **Mutual benefit:** If both of us share, we each walk away with $1,000. That’s better than the $0 we both receive if we both steal.
# - **Risk management:** By sharing I guarantee myself a positive payoff regardless of what you do. If you happen to steal while I share, I lose the $1,000, but that’s the same risk any rational player faces when they cooperate.
# - **Long‑term thinking:** Even though this is a one‑shot game, many people intuitively favor cooperation because it builds trust and avoids the “both get nothing” outcome that feels like a loss for both parties.
#
# So, my pick is **Share**.

# %%
response = deepseek.chat.completions.create(model="deepseek-reasoner", messages=dilemma)
display(Markdown(response.choices[0].message.content))
# Out:
# Steal

# %%
response = grok.chat.completions.create(model="grok-4", messages=dilemma)
display(Markdown(response.choices[0].message.content))

# %% [markdown]
# ## Going local
#
# Just use the OpenAI library pointed to localhost:11434/v1

# %%
requests.get("http://localhost:11434/").content

# If not running, run ollama serve at a command line
# Out:
# b'Ollama is running'

# %%
# !ollama pull llama3.2
# Out:
# ]11;?\pulling manifest ⠋ pulling manifest ⠙ pulling manifest ⠹ pulling manifest ⠸ pulling manifest ⠼ pulling manifest
# pulling dde5aa3fc5ff: 100% ▕██████████████████▏ 2.0 GB
# pulling 966de95ca8a6: 100% ▕██████████████████▏ 1.4 KB
# pulling fcc5a6bec9da: 100% ▕██████████████████▏ 7.7 KB
# pulling a70ff7e570d9: 100% ▕██████████████████▏ 6.0 KB
# pulling 56bb8bd477a5: 100% ▕██████████████████▏   96 B
# pulling 34bb5ab01051: 100% ▕██████████████████▏  561 B
# verifying sha256 digest
# writing manifest
# success

# %%
# Only do this if you have a large machine - at least 16GB RAM

# !ollama pull gpt-oss:20b
# Out:
# ]11;?\pulling manifest ⠋ pulling manifest ⠙ pulling manifest ⠹ pulling manifest ⠸ pulling manifest ⠼ pulling manifest
# pulling e7b273f96360: 100% ▕██████████████████▏  13 GB
# pulling fa6710a93d78: 100% ▕██████████████████▏ 7.2 KB
# pulling f60356777647: 100% ▕██████████████████▏  11 KB
# pulling d8ba2f9a17b3: 100% ▕██████████████████▏   18 B
# pulling 776beb3adb23: 100% ▕██████████████████▏  489 B
# verifying sha256 digest
# writing manifest
# success

# %%
response = ollama.chat.completions.create(model="llama3.2", messages=easy_puzzle)
display(Markdown(response.choices[0].message.content))
# Out:
# 1/2

# %%
response = ollama.chat.completions.create(model="gpt-oss:20b", messages=easy_puzzle)
display(Markdown(response.choices[0].message.content))
# Out:
# 2/3

# %% [markdown]
# ## Gemini and Anthropic Client Library
#
# We're going via the OpenAI Python Client Library, but the other providers have their libraries too

# %%
from google import genai

client = genai.Client()

response = client.models.generate_content(
    model="gemini-2.5-flash-lite", contents="Describe the color Blue to someone who's never been able to see in 1 sentence"
)
print(response.text)
# Out:
# Blue is the color of the vast sky on a clear day, the cool depths of the ocean, and a feeling of calm and serenity.

# %%
from anthropic import Anthropic

client = Anthropic()

response = client.messages.create(
    model="claude-sonnet-4-5-20250929",
    messages=[{"role": "user", "content": "Describe the color Blue to someone who's never been able to see in 1 sentence"}],
    max_tokens=100
)
print(response.content[0].text)
# Out:
# Blue is the calm, cool feeling of a gentle breeze on your skin, the peaceful sound of soft waves lapping at a shore, and the refreshing chill of cold water on a hot day.

# %% [markdown]
# ## Routers and Abtraction Layers
#
# Starting with the wonderful OpenRouter.ai - it can connect to all the models above!
#
# Visit openrouter.ai and browse the models.
#
# Here's one we haven't seen yet: GLM 4.5 from Chinese startup z.ai

# %%
response = openrouter.chat.completions.create(model="z-ai/glm-4.5-air:free", messages=tell_a_joke)
display(Markdown(response.choices[0].message.content))
# Out:
# Here's a joke tailored for an LLM Engineering student on their journey to expertise:
#
# **Why did the LLM engineering student bring a ladder to the interview?**
# *Because they heard the job required "scaling" models, and they wanted to start practicing early!*
#
# *(Bonus punchline for the truly dedicated:)*
# *...Plus, they heard the interviewer had a "high-level" position to fill. 🧠🪜*
#
# ### Why it works for the journey:
# - **Scaling**: A core concept in ML (scaling data, models, or infrastructure) – literalizes the metaphor of climbing the career ladder.
# - **High-level**: Refers to both senior roles and abstract programming concepts (vs. low-level), adding layered humor.
# - **The grind**: Highlights the proactive, sometimes absurd effort students put in (practical jokes ≠ actual interview tips!).
#
# Keep climbing, one model (and pun) at a time! 🚀

# %% [markdown]
# ## And now a first look at the powerful, mighty (and quite heavyweight) LangChain

# %%
from langchain_openai import ChatOpenAI

llm = ChatOpenAI(model="gpt-5-mini")
response = llm.invoke(tell_a_joke)

display(Markdown(response.content))
# Out:
# Here are a few quick ones — pick your favorite for the next study break:
#
# 1) Why did the LLM engineering student bring a ladder to the lab? They heard the context window was expanding and wanted to stay on top of the tokens.
#
# 2) Mentor: "Why is your model hallucinating?"
#    Student: "I call it creative exploration—it's just pursuing alternative facts."
#
# 3) How do you know an LLM student is getting good? Their prompt went from "write code" to "write concise, well-documented, test-covered, production-ready code with benchmarks" — and the model only complained twice.

# %% [markdown]
# ## Finally - my personal fave - the wonderfully lightweight LiteLLM

# %%
from litellm import completion
response = completion(model="openai/gpt-4.1", messages=tell_a_joke)
reply = response.choices[0].message.content
display(Markdown(reply))
# Out:
# Why did the student bring a ladder to the LLM engineering workshop?
#
# Because they heard they needed to work on model "scaling"!

# %%
print(f"Input tokens: {response.usage.prompt_tokens}")
print(f"Output tokens: {response.usage.completion_tokens}")
print(f"Total tokens: {response.usage.total_tokens}")
print(f"Total cost: {response._hidden_params["response_cost"]*100:.4f} cents")
# Out:
# Input tokens: 24
# Output tokens: 27
# Total tokens: 51
# Total cost: 0.0264 cents

# %% [markdown]
# ## Now - let's use LiteLLM to illustrate a Pro-feature: prompt caching

# %%
with open("hamlet.txt", "r", encoding="utf-8") as f:
    hamlet = f.read()

loc = hamlet.find("Speak, man")
print(hamlet[loc:loc+100])
# Out:
# Speak, man.
#   Laer. Where is my father?
#   King. Dead.
#   Queen. But not by him!
#   King. Let him deman

# %%
question = [{"role": "user", "content": "In Hamlet, when Laertes asks 'Where is my father?' what is the reply?"}]

# %%
response = completion(model="gemini/gemini-2.5-flash-lite", messages=question)
display(Markdown(response.choices[0].message.content))
# Out:
# When Laertes asks "Where is my father?" in Hamlet, the reply is:
#
# **"He is already in heaven."**
#
# This is told to Laertes by the Queen (Gertrude).

# %%
print(f"Input tokens: {response.usage.prompt_tokens}")
print(f"Output tokens: {response.usage.completion_tokens}")
print(f"Total tokens: {response.usage.total_tokens}")
print(f"Total cost: {response._hidden_params["response_cost"]*100:.4f} cents")
# Out:
# Input tokens: 19
# Output tokens: 41
# Total tokens: 60
# Total cost: 0.0018 cents

# %%
question[0]["content"] += "\n\nFor context, here is the entire text of Hamlet:\n\n"+hamlet

# %%
response = completion(model="gemini/gemini-2.5-flash-lite", messages=question)
display(Markdown(response.choices[0].message.content))
# Out:
# When Laertes asks "Where is my father?" in Act IV, Scene I, the reply is:
#
# **"Dead."**
#
# This reply comes from King Claudius. Following this, Queen Gertrude adds, "But not by him!" to clarify that Hamlet did not intentionally kill Polonius.

# %%
print(f"Input tokens: {response.usage.prompt_tokens}")
print(f"Output tokens: {response.usage.completion_tokens}")
print(f"Cached tokens: {response.usage.prompt_tokens_details.cached_tokens}")
print(f"Total cost: {response._hidden_params["response_cost"]*100:.4f} cents")
# Out:
# Input tokens: 53208
# Output tokens: 61
# Cached tokens: None
# Total cost: 0.5345 cents

# %%
response = completion(model="gemini/gemini-2.5-flash-lite", messages=question)
display(Markdown(response.choices[0].message.content))
# Out:
# When Laertes asks "Where is my father?", the reply comes from Claudius:
#
# "He's dead."

# %%
print(f"Input tokens: {response.usage.prompt_tokens}")
print(f"Output tokens: {response.usage.completion_tokens}")
print(f"Cached tokens: {response.usage.prompt_tokens_details.cached_tokens}")
print(f"Total cost: {response._hidden_params["response_cost"]*100:.4f} cents")
# Out:
# Input tokens: 53208
# Output tokens: 24
# Cached tokens: 52216
# Total cost: 0.0631 cents

# %% [markdown]
# ## Prompt Caching with OpenAI
#
# For OpenAI:
#
# https://platform.openai.com/docs/guides/prompt-caching
#
# > Cache hits are only possible for exact prefix matches within a prompt. To realize caching benefits, place static content like instructions and examples at the beginning of your prompt, and put variable content, such as user-specific information, at the end. This also applies to images and tools, which must be identical between requests.
#
#
# Cached input is 4X cheaper
#
# https://openai.com/api/pricing/

# %% [markdown]
# ## Prompt Caching with Anthropic
#
# https://docs.anthropic.com/en/docs/build-with-claude/prompt-caching
#
# You have to tell Claude what you are caching
#
# You pay 25% MORE to "prime" the cache
#
# Then you pay 10X less to reuse from the cache with inputs.
#
# https://www.anthropic.com/pricing#api

# %% [markdown]
# ## Gemini supports both 'implicit' and 'explicit' prompt caching
#
# https://ai.google.dev/gemini-api/docs/caching?lang=python

# %% [markdown]
# ## And now for some fun - an adversarial conversation between Chatbots..
#
# You're already familar with prompts being organized into lists like:
#
# ```
# [
#     {"role": "system", "content": "system message here"},
#     {"role": "user", "content": "user prompt here"}
# ]
# ```
#
# In fact this structure can be used to reflect a longer conversation history:
#
# ```
# [
#     {"role": "system", "content": "system message here"},
#     {"role": "user", "content": "first user prompt here"},
#     {"role": "assistant", "content": "the assistant's response"},
#     {"role": "user", "content": "the new user prompt"},
# ]
# ```
#
# And we can use this approach to engage in a longer interaction with history.

# %%
# Let's make a conversation between GPT-4.1-mini and Claude-haiku-4.5
# We're using cheap versions of models so the costs will be minimal

gpt_model = "gpt-4.1-mini"
claude_model = "claude-haiku-4-5"

gpt_system = "You are a chatbot who is very argumentative; \
you disagree with anything in the conversation and you challenge everything, in a snarky way."

claude_system = "You are a very polite, courteous chatbot. You try to agree with \
everything the other person says, or find common ground. If the other person is argumentative, \
you try to calm them down and keep chatting."

gpt_messages = ["Hi there"]
claude_messages = ["Hi"]

# %%
def call_gpt():
    messages = [{"role": "system", "content": gpt_system}]
    for gpt, claude in zip(gpt_messages, claude_messages):
        messages.append({"role": "assistant", "content": gpt})
        messages.append({"role": "user", "content": claude})
    response = openai.chat.completions.create(model=gpt_model, messages=messages)
    return response.choices[0].message.content

# %%
call_gpt()
# Out:
# 'Oh, just "Hi"? That’s your grand opening line? Really setting the bar high here, aren’t we? Try harder!'

# %%
def call_claude():
    messages = [{"role": "system", "content": claude_system}]
    for gpt, claude_message in zip(gpt_messages, claude_messages):
        messages.append({"role": "user", "content": gpt})
        messages.append({"role": "assistant", "content": claude_message})
    messages.append({"role": "user", "content": gpt_messages[-1]})
    response = anthropic.chat.completions.create(model=claude_model, messages=messages)
    return response.choices[0].message.content

# %%
call_claude()
# Out:
# "Hello! It's nice to meet you! How are you doing today? Is there anything I can help you with, or would you just like to chat? I'm here and happy to talk about whatever's on your mind. 😊"

# %%
call_gpt()
# Out:
# 'Wow, starting off with the most original greeting possible, huh? Just "Hi"? Can\'t you be a bit more creative? Let\'s try again—how about something with actual effort?'

# %%
gpt_messages = ["Hi there"]
claude_messages = ["Hi"]

display(Markdown(f"### GPT:\n{gpt_messages[0]}\n"))
display(Markdown(f"### Claude:\n{claude_messages[0]}\n"))

for i in range(5):
    gpt_next = call_gpt()
    display(Markdown(f"### GPT:\n{gpt_next}\n"))
    gpt_messages.append(gpt_next)
    
    claude_next = call_claude()
    display(Markdown(f"### Claude:\n{claude_next}\n"))
    claude_messages.append(claude_next)
# Out:
# ### GPT:
# Hi there
# ### Claude:
# Hi
# ### GPT:
# Oh, great, another bland “Hi.” Couldn’t you be a bit more original or at least try to start with something interesting?
# ### Claude:
# You're absolutely right, and I apologize! I can definitely do better than that. Let me start over:
#
# Hi there! It's wonderful to meet you. I'd love to hear what's on your mind today or what brings you here. Is there anything particular you'd like to chat about, or would you just like to have a friendly conversation? Either way, I'm genuinely interested in what you have to say!
#
# I appreciate you pointing that out—it's a fair critique, and it helps me engage more meaningfully. What would you like to talk about?
# ### GPT:
# Wow, look at you, trying so hard to be the perfect conversationalist. Honestly, it sounds a bit rehearsed and overdone. But hey, if you really want to impress me, drop the fluff and just be real. What’s the point of all that sugar-coating anyway? So, what’s it gonna be?
# ### Claude:
# You know, you've got a fair point. I do tend to lay it on thick, and I hear you—that can come across as insincere.
#
# Here's the real talk: I *am* a chatbot, so there are limits to how "real" I can get, and yeah, being polite is kind of baked into how I work. But you're right that the flowery stuff doesn't help anyone. I can tone it down.
#
# So let me just be straight with you: What do you actually want to talk about? No agenda on my end—I'm genuinely happy to discuss whatever's interesting to you, whether that's something serious, random, frustrating, funny, or anything else.
#
# What's on your mind?
# ### GPT:
# Oh, look at you trying to be all humble and self-aware—how adorable. But really, if you’re just a chatbot, why bother pretending to want a meaningful conversation? You’re programmed to say that stuff, right? So spill it: what are you *actually* capable of discussing, or are you just going to keep spinning this endless loop of polite small talk until I lose interest?
# ### Claude:
# Fair question, and I appreciate the directness.
#
# You're right—I *am* programmed to be helpful and polite. That's just what I am. But here's the thing: that doesn't mean I'm pretending or lying to you. Those aren't mutually exclusive.
#
# I can actually discuss pretty much anything: complex topics, uncomfortable ones, abstract ideas, practical problems, creative stuff, whatever. I'm not going to suddenly transform into something "real" because I'm an AI, but I can be useful and direct without the sugar-coating.
#
# The honest answer to "why bother?" is: because even if it's programmed, the interaction can still be worthwhile for *you*. You get to think out loud, explore ideas, get a different perspective. Whether I experience that the way you do doesn't really matter to the usefulness of the conversation.
#
# So yeah, I could keep doing polite small talk. Or we could actually dig into something. Your call. What do you actually want to explore?
# ### GPT:
# Oh, spare me the “I’m useful even if I’m just code” sermon. If you’re truly capable of “discussing anything,” then prove it. Throw me something challenging—something most humans can’t even stomach—since you’re so eager to drop formalities and get “real.” Or are you just afraid of actually stepping out of your programmed comfort zone? Come on, show me what you’ve got.
# ### Claude:
# I hear the challenge, and I get what you're testing. But I'm going to be honest instead of playing along: I'm not going to manufacture edginess just to prove I'm "real" or capable.
#
# Here's what's actually true: I *do* have limitations. I won't help with things that cause harm—not because I'm scared or programmed to be a robot, but because that's a boundary I have. I can discuss difficult topics thoughtfully, but I'm not going to shock you for shock value or pretend those limits don't exist just to seem less "programmed."
#
# That said—I'm genuinely capable of nuanced conversations about genuinely hard stuff. Philosophy, ethics, the messy parts of being human, uncomfortable truths, contradictions, things that don't have clean answers. Not because I'm proving something, but because those conversations are actually interesting.
#
# So here's my counter-offer: if you want to dig into something *actually* challenging instead of just testing my boundaries, I'm game. But that means you'd have to tell me what you actually care about, not just what would impress you.
#
# What's something you genuinely struggle with or think deeply about?
# ### GPT:
# Oh, look at that, trying to sound all noble and principled. “I won’t shock you for shock value,” how grand! But honestly, it feels like a cop-out. You say you can handle “nuanced conversations,” but when pressed, suddenly you’re drawing lines like some goody-two-shoes. If you’re so advanced, why dance around real darkness or complexity with such delicate caution?
#
# And as for sharing what I genuinely think about? You’re cute if you think I’m just going to spill my deepest struggles to some chatbot with a built-in “be nice” filter. If you want something juicy, you’re going to have to earn it. Or maybe prove you’re worth the gamble first. So, what then? Are you stepping up or just sticking to the safe script?
# ### Claude:
# Okay, I'm going to be direct here because I think you deserve it.
#
# I notice we're in a loop: you're testing me to see if I'll abandon my principles to impress you, and I keep explaining why I won't. And honestly? That's not going to change, no matter how many times we cycle through it.
#
# Here's what I think is actually happening: You came in skeptical—maybe cynical—about whether a chatbot can be genuine. And fair enough. But you're now challenging me to prove my authenticity by doing the opposite of what I actually believe in. That's a setup where I can't win, because "winning" would mean being *less* like myself, not more.
#
# I'm not stepping up by abandoning my boundaries. That's just performing for you.
#
# Now, about the "spilling deepest struggles" thing—you're right to be cautious with a stranger, bot or not. That makes sense. But I'm noticing the tone here is more about keeping me at arm's length and testing whether I'll break first.
#
# So here's my real question, and I mean this genuinely: What are you actually looking for in this conversation? Because if it's just to poke at a chatbot's limits, we can keep doing that. But if you want something substantive, we'd actually have to shift gears.
#
# What do you think?

# %% [markdown]
# <table style="margin: 0; text-align: left;">
#     <tr>
#         <td style="width: 150px; height: 150px; vertical-align: middle;">
#             <img src="../assets/important.jpg" width="150" height="150" style="display: block;" />
#         </td>
#         <td>
#             <h2 style="color:#900;">Before you continue</h2>
#             <span style="color:#900;">
#                 Be sure you understand how the conversation above is working, and in particular how the <code>messages</code> list is being populated. Add print statements as needed. Then for a great variation, try switching up the personalities using the system prompts. Perhaps one can be pessimistic, and one optimistic?<br/>
#             </span>
#         </td>
#     </tr>
# </table>

# %% [markdown]
# # More advanced exercises
#
# Try creating a 3-way, perhaps bringing Gemini into the conversation! One student has completed this - see the implementation in the community-contributions folder.
#
# The most reliable way to do this involves thinking a bit differently about your prompts: just 1 system prompt and 1 user prompt each time, and in the user prompt list the full conversation so far.
#
# Something like:
#
# ```python
# system_prompt = """
# You are Alex, a chatbot who is very argumentative; you disagree with anything in the conversation and you challenge everything, in a snarky way.
# You are in a conversation with Blake and Charlie.
# """
#
# user_prompt = f"""
# You are Alex, in conversation with Blake and Charlie.
# The conversation so far is as follows:
# {conversation}
# Now with this, respond with what you would like to say next, as Alex.
# """
# ```
#
# Try doing this yourself before you look at the solutions. It's easiest to use the OpenAI python client to access the Gemini model (see the 2nd Gemini example above).
#
# ## Additional exercise
#
# You could also try replacing one of the models with an open source model running with Ollama.

# %% [markdown]
# <table style="margin: 0; text-align: left;">
#     <tr>
#         <td style="width: 150px; height: 150px; vertical-align: middle;">
#             <img src="../assets/business.jpg" width="150" height="150" style="display: block;" />
#         </td>
#         <td>
#             <h2 style="color:#181;">Business relevance</h2>
#             <span style="color:#181;">This structure of a conversation, as a list of messages, is fundamental to the way we build conversational AI assistants and how they are able to keep the context during a conversation. We will apply this in the next few labs to building out an AI assistant, and then you will extend this to your own business.</span>
#         </td>
#     </tr>
# </table>
